# %%
import pandas as pd

x = pd.read_csv(r"C:\Users\srodriguez\Desktop\Cancelaciones.csv")

x[20:25]
# Out:
#    SalesCenter  ContractId    OwnerId                  Name    Country  \
# 20   Dominicus   950071973  950276170      Giovanni Casazza      Italy
# 21   Dominicus     8001585    8001585            KLAUS MEHR     France
# 22   Dominicus   950059763  950228365      Miguel  Arroniz   Argentina
# 23   Dominicus   950066265  950276731  Dean Stanley Burgher     Canada
# 24   Dominicus   950077662  950347244  Federico Oscar Gomez  Argentina
#
#                          Email   Idioma
# 20  giovanni.casazza@libero.it  Italian
# 21              mehrkd@aol.com   French
# 22         marroniz1@gmail.com  Spanish
# 23        burgher_sam@yahoo.ca  English
# 24  gomezfederico.27@gmail.com  Spanish

# %%
x[(x['Idioma'] == 'Spanish') & (x['SalesCenter'] == 'Maya')].head(10)
# Out:
#    SalesCenter  ContractId    OwnerId                                 Name  \
# 43        Maya   950071872  950300787                 Ricardo Javier Moya
# 46        Maya   950075146  950333586                Carlos Alberto Newton
# 47        Maya   950078824  950353496  Daniel Humberto Valenzuela Carrasco
# 48        Maya   950067977  950289724                 Carlos Miguel  Nu�ez
# 49        Maya   950076181  950340385             Jorge Domingo Villarruel
# 50        Maya   950078470  950351580       Celia Estela  Gonzalez Vazquez
# 52        Maya   950068193  950291299              Claudio Marcelo La Sala
# 53        Maya   950075341  950322820                   Luis Alberto Anton
# 54        Maya   950071633  950312579              Mar�a Eugenia Piccinini
# 55        Maya   950068825  950295508                      Yamila Martinez
#
#       Country                                  Email   Idioma
# 43  Argentina            transportejmsrl@hotmail.com  Spanish
# ...

# %%
# Filtro normal x[x['Idioma'] == 'Spanish'].head(10)

# Filtro AND x[(x['Idioma'] == 'Spanish') & (x['SalesCenter'] == 'Maya')].head(10)

# Filtro OR x[(x['Idioma'] == 'Spanish') | (x['SalesCenter'] == 'Maya')].head(10)

# %%
x[x.SalesCenter.isin(['Dominicus','Maya'])].head(10)
# Out:
#   SalesCenter  ContractId    OwnerId                              Name  \
# 0   Dominicus   950076014  950339315          Marcelo Oscar Scataglini
# 1   Dominicus   950066088  950275214  Nielsen Daladier Aguilera Robles
# 2   Dominicus   950077469  950346363          Huascar Soriano Martinez
# 3   Dominicus   950063766  950256823                       Kyd Fontana
# 4   Dominicus   950078638  950352425       Mauro Martin Coria Rizzotto
# 5   Dominicus   950070067  950302996          Osvaldo Angel Perez Mayo
# 6   Dominicus   950076200  950327073         Mauro Andr�s Pizarro Cruz
# 7   Dominicus   950074723  950331043                    Alberto Sinisi
# 8   Dominicus   950074230  950328073                      Per  Oerving
# 9   Dominicus   950072126  950315155            Damian Marcelo Belsito
#
#                     Country                             Email   Idioma
# 0                 Argentina       miriamaladio@hotmail.com.ar  Spanish
# ...
